# %%
# %sql
create volume if not exists usage_Matrix

# %% [markdown]
# %md
# # **My 1stDataBricks workons**
#
# ## **Task Description**
# Gonna learn abour Data Bricks
#
#
# <span style="color:pink; font-size:18px;">**My Name is Poongothai Narasimman**</span>
#
#
# ## **Team Photo**
#
#
# ![Team Photo](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)
#
#
#
# ## **Notes**
# ### **Formatting Used**
# - **Bold text**
# - *Italic text*
# - `Code formatting`
# - Headings of various levels
#
# You can modify colors, fonts, or descriptions as needed.

# %% [markdown]
# #Task2: Create a volume namely usage_metrics using sql magic command %sql#

# %%
# %sql

create volume if not exists usage_Matrix

# %%
ls/volumes

# %% [markdown]
# ##Task4##

# %%
# %run "/Workspace/Users/poongothai1218@gmail.com/Local Notebooks/Untitled Notebook 2025-12-01 19:22:26"

# %% [markdown]
# Task5

# %%
# %sh
ls /databricks-datasets

# %% [markdown]
# Task 6

# %%
dbutils.fs.mv("/Volumes/workspace/default/volumewd36/mobile_os_usage.csv", "/Volumes/workspace/default/volumewd36/mobile_os_usage.csv.bak")

# %%
# %sql
create table default.mobile_os_usage (Date string, OS string, Usage int)

# %% [markdown]
# Task7

# %%
# %py
df=spark.read.csv("/Volumes/workspace/default/volumewd36/mobile_os_usage.csv.bak").write.mode("overwrite").saveAsTable("mobile_os_usage1")
df1 = spark.read.table("mobile_os_usage1")
df1.count()

# %% [markdown]
# Task 8

# %%
# %sql
select * from mobile_os_usage1

# %% [markdown]
# Task 9

# %%
# %py
name="poongothai"
print(name.upper())

# %% [markdown]
# Task 10

# %%
# %pip install pandas

# %% [markdown]
# Task 11

# %%
# %py
import pandas as pd
df = pd.read_csv("/Volumes/workspace/default/volumewd36/mobile_os_usage.csv.bak")
df.head()

# %% [markdown]
# Task 12

# %%
# %sh
echo "Task Completed"
