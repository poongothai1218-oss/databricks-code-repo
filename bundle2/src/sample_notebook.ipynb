# %%
dbutils.widgets.text("catalog","progcatalog1")
dbutils.widgets.text("schema","logistics1")
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
print(catalog)
print(schema)

# %%
data=[(1,"a"),(2,"b"),(3,"c"),(4,"d")]
spark.createDataFrame(data).toDF.write.mode("overwrite").saveAsTable(f"{catalog}.{schema}.test")
